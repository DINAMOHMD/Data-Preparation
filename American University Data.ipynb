# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1.Reading the Dataset

# %%
df=pd.read_excel("IPEDS_data.xlsx")

# %%
df.shape
# Out:
# (1534, 145)

# %%
df.head()
# Out:
#    ID number                                 Name  year    ZIP code  \
# 0     100654             Alabama A & M University  2013       35762
# 1     100663  University of Alabama at Birmingham  2013  35294-0110
# 2     100690                   Amridge University  2013  36117-3553
# 3     100706  University of Alabama in Huntsville  2013       35899
# 4     100724             Alabama State University  2013  36104-0271
#
#                               Highest degree offered        County name  \
# 0             Doctor's degree - research/scholarship     Madison County
# 1  Doctor's degree - research/scholarship and pro...   Jefferson County
# 2  Doctor's degree - research/scholarship and pro...  Montgomery County
# 3  Doctor's degree - research/scholarship and pro...     Madison County
# 4  Doctor's degree - research/scholarship and pro...  Montgomery County
#
#    Longitude location of institution  Latitude location of institution  \
# ...

# %%
df.describe()
# Out:
#            ID number    year  Longitude location of institution  \
# count    1534.000000  1534.0                        1534.000000
# mean   189091.037810  2013.0                         -88.342338
# std     58641.915456     0.0                          14.838804
# min    100654.000000  2013.0                        -158.062444
# 25%    153148.500000  2013.0                         -94.576342
# 50%    186508.000000  2013.0                         -84.514218
# 75%    215730.000000  2013.0                         -77.207136
# max    456490.000000  2013.0                         -67.456534
#
#        Latitude location of institution  Applicants total  Admissions total  \
# count                       1534.000000       1377.000000       1377.000000
# mean                          38.729993       6391.193174       3554.880174
# std                            4.832832       8787.469171       4309.457606
# min                           19.701854          0.000000          0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1534 entries, 0 to 1533
# Columns: 145 entries, ID number to Endowment assets (year end) per FTE enrollment (FASB)
# dtypes: float64(116), int64(2), object(27)
# memory usage: 1.7+ MB

# %%
cols_list=df.columns.tolist()
print("list of features ", cols_list)
# Out:
# list of features  ['ID number', 'Name', 'year', 'ZIP code', 'Highest degree offered', 'County name', 'Longitude location of institution', 'Latitude location of institution', 'Religious affiliation', 'Offers Less than one year certificate', 'Offers One but less than two years certificate', "Offers Associate's degree", 'Offers Two but less than 4 years certificate', "Offers Bachelor's degree", 'Offers Postbaccalaureate certificate', "Offers Master's degree", "Offers Post-master's certificate", "Offers Doctor's degree - research/scholarship", "Offers Doctor's degree - professional practice", "Offers Doctor's degree - other", 'Offers Other degree', 'Applicants total', 'Admissions total', 'Enrolled total', 'Percent of freshmen submitting SAT scores', 'Percent of freshmen submitting ACT scores', 'SAT Critical Reading 25th percentile score', 'SAT Critical Reading 75th percentile score', 'SAT Math 25th percentile score', 'SAT Math 75th percentile score', 'SAT Writing 25th percentile score', 
# ...

# %% [markdown]
# # 2.Exploratory Data Analysis (EDA) and Visualization

# %% [markdown]
# ###### Do universities with a high number of applications are the preferred ones by students? in other words, could the number of applications tell us that a university is one of the most preferred by students?

# %%
num_of_applications =  df.groupby('Name')['Applicants total'].sum().sort_values(ascending = False)
num_of_applications
# Out:
# Name
# University of California-Los Angeles           72676.0
# University of California-Berkeley              61717.0
# University of California-San Diego             60832.0
# New York University                            57845.0
# University of California-Irvine                56515.0
#                                                 ...
# Miles College                                      0.0
# Missouri Western State University                  0.0
# Montana State University-Billings                  0.0
# Monterey Institute of International Studies        0.0
# Youngstown State University                        0.0
# Name: Applicants total, Length: 1517, dtype: float64

# %%
num_of_applications = df[['Name','Applicants total']].sort_values("Applicants total",ascending = False).head(25)
num_of_applications
# Out:
#                                                    Name  Applicants total
# 84                 University of California-Los Angeles           72676.0
# 81                    University of California-Berkeley           61717.0
# 86                   University of California-San Diego           60832.0
# 841                                 New York University           57845.0
# 83                      University of California-Irvine           56515.0
# 87               University of California-Santa Barbara           55258.0
# 77               California State University-Long Beach           55019.0
# 863                       St John's University-New York           51634.0
# 126                          San Diego State University           51163.0
# 82                       University of California-Davis           49820.0
# 1371                                 Liberty University           48054.0
# 1133          Pennsylvania State University-Main Campus           47552.0
# ...

# %%
plt.figure(figsize=(20,16))
sns.barplot(x='Applicants total',y='Name',data =num_of_applications)
plt.title('Top 25 Universities with the Most Applications')
plt.xlabel('Number of applications');

# %%
sns.histplot(df['Applicants total'],bins=40)

# %%
sns.histplot(df['Admissions total'],bins=40)

# %%
sns.histplot(df['Enrolled total'],bins=40)

# %% [markdown]
# the number of applications don't tell us that a university is one of the most preferred by students

# %% [markdown]
# ###### Do students prefer universities that have a high rate of admission?, in other words, do students prefer a university where it is easier for them to be admitted?.

# %%
sns.scatterplot(x=df['Applicants total'],y=df['Admissions total'],data=df,hue=df['Control of institution'])

# %%
sns.scatterplot(x=df['Applicants total'],y=df['Enrolled total'],data=df,hue=df['Control of institution'])

# %%
sns.scatterplot(x=df['Admissions total'],y=df['Enrolled total'],data=df,hue=df['Control of institution'])

# %%
df['acceptance_rate'] =(df['Admissions total']/df['Applicants total']* 100) 
df['enrollment_rate'] =(df['Enrolled total']/df['Admissions total']* 100)

# %%
sns.scatterplot(x = df.acceptance_rate,y = df.enrollment_rate,data=df,hue=df['Control of institution'])

# %% [markdown]
# students don't prefer a university where it is easier for them to be admitted

# %% [markdown]
# ###### Do students prefer public or private universities?

# %%
sns.barplot(x=df['Control of institution'],y=df['Applicants total'])

# %% [markdown]
# students prefer public universities

# %% [markdown]
# ###### Do students prefer universities with low tuition and fees?

# %%
sns.scatterplot(x=df['Tuition and fees, 2013-14'],y=df['Applicants total'],hue=df['Control of institution']);

# %% [markdown]
#  students prefer universities with low tuition and fees

# %% [markdown]
# ###### Do students prefer a university for its low on-campus cost of living?

# %%
sns.scatterplot(x=df['Total price for out-of-state students living on campus 2013-14'],
                y=df.enrollment_rate,hue=df['Control of institution']);

# %% [markdown]
# students prefer a university for its low on-campus cost of living

# %% [markdown]
# ###### Do students prefer universities from highly populated states?

# %%
plt.figure(figsize=(16,8))
sns.barplot(x=df['State abbreviation'],y= df['enrollment_rate'])
plt.xticks(rotation=90);
# Out:
# C:\Users\Dina\anaconda3\lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))

# %% [markdown]
# students prefer universities from highly populated states such (North Dakota)

# %% [markdown]
# ###### Do students prefer a university because it belongs to a state with a high GDP per capita?

# %% [markdown]
# students prefer a university because it belongs to a state with a high GDP per capita such (North Dakota)

# %% [markdown]
# ###### Do students prefer a university based on the possibility of a higher, additional academic degree in the same university?

# %%
 sns.boxplot(data=df, x=df["Offers Master's degree"], y='Admissions yield - total')

# %%
sns.boxplot(data=df, x=df["Offers Doctor's degree - research/scholarship"], y='Admissions yield - total')

# %%
sns.boxplot(data=df, x=df["Offers Doctor's degree - professional practice"], y='Admissions yield - total')

# %%
sns.boxplot(data=df, x=df["Offers Doctor's degree - other"], y='Admissions yield - total')

# %%
sns.boxplot(data=df, x=df["Offers Other degree"], y='Admissions yield - total')

# %%
sns.boxplot(data=df, x=df["Offers Post-master's certificate"], y='Admissions yield - total')

# %%
sns.boxplot(data=df, x=df["Offers Associate's degree"], y='Admissions yield - total')

# %%
sns.boxplot(data=df, x=df["Offers One but less than two years certificate"], y='Admissions yield - total')

# %%
sns.boxplot(data=df, x=df["Offers Postbaccalaureate certificate"], y='Admissions yield - total')

# %%
sns.boxplot(data=df, x=df["Offers Two but less than 4 years certificate"], y='Admissions yield - total')

# %%
sns.boxplot(data=df, x=df["Offers Less than one year certificate"], y='Admissions yield - total')

# %% [markdown]
# students prefer a university based on the possibility of a higher, additional academic degree in the same university

# %% [markdown]
# # 3.Data Preparation: Cleaning and Formatting

# %%
df.isna().sum().sort_values(ascending = False)
# Out:
# Endowment assets (year end) per FTE enrollment (GASB)       1018
# SAT Writing 75th percentile score                            820
# SAT Writing 25th percentile score                            820
# Percent of first-time undergraduates - residence unknown     623
# Number of first-time undergraduates - residence unknown      623
#                                                             ...
# Historically Black College or University                       0
# Tribal college                                                 0
# Degree of urbanization (Urban-centric locale)                  0
# Carnegie Classification 2010: Basic                            0
# ID number                                                      0
# Length: 147, dtype: int64

# %%
cols_list=df.columns.tolist()
print("list of features ", cols_list)
# Out:
# list of features  ['ID number', 'Name', 'year', 'ZIP code', 'Highest degree offered', 'County name', 'Longitude location of institution', 'Latitude location of institution', 'Religious affiliation', 'Offers Less than one year certificate', 'Offers One but less than two years certificate', "Offers Associate's degree", 'Offers Two but less than 4 years certificate', "Offers Bachelor's degree", 'Offers Postbaccalaureate certificate', "Offers Master's degree", "Offers Post-master's certificate", "Offers Doctor's degree - research/scholarship", "Offers Doctor's degree - professional practice", "Offers Doctor's degree - other", 'Offers Other degree', 'Applicants total', 'Admissions total', 'Enrolled total', 'Percent of freshmen submitting SAT scores', 'Percent of freshmen submitting ACT scores', 'SAT Critical Reading 25th percentile score', 'SAT Critical Reading 75th percentile score', 'SAT Math 25th percentile score', 'SAT Math 75th percentile score', 'SAT Writing 25th percentile score', 
# ...

# %%
df=df.drop(columns=['ID number','Longitude location of institution','Latitude location of institution',
                'Endowment assets (year end) per FTE enrollment (GASB)', 'Endowment assets (year end) per FTE enrollment (FASB)',
               'County name'])

# %%
df[df['Total  enrollment'].isna()]
# Out:
#                                   Name  year    ZIP code  \
# 257        University of North Georgia  2013  30597-1001
# 1308  Texas A & M University-Galveston  2013       77554
#
#                         Highest degree offered Religious affiliation  \
# 257   Doctor's degree -  professional practice                   NaN
# 1308    Doctor's degree - research/scholarship                   NaN
#
#      Offers Less than one year certificate  \
# 257                                    NaN
# 1308                                   NaN
#
#      Offers One but less than two years certificate Offers Associate's degree  \
# 257                                             NaN                       NaN
# 1308                                            NaN                       NaN
#
#      Offers Two but less than 4 years certificate Offers Bachelor's degree  \
# 257                                           NaN                      NaN
# ...

# %%
df=df.drop([257,1308],axis=0)

# %%
df.replace(0,np.nan,inplace=True)

# %% [markdown]
# # 4.Conclusions

# %% [raw]
# *the number of applications don't tell us that a university is one of the most preferred by students
# Because students apply to more than one university for fear of not being accepted into the university they want
# *students don't prefer a university where it is easier for them to be admitted,But in the university they want
# *students prefer public universities Because private universities have very high fees
# *students prefer universities with low tuition and fees,This is evident in their greater preference for public universities
# *students prefer a university for its low on-campus cost of living
# *students prefer universities from highly populated states such (North Dakota)
# North Dakota has been among the nation's fastest-growing states, estimated to have grown by more than 16% since 2010
# *students prefer a university because it belongs to a state with a high GDP per capita such (North Dakota)
# *students prefer a university based on the possibility of a higher, additional academic degree in the same university
